# %%
import pandas

#reading the csv into a data frame
df = pandas.read_csv("bank.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df['LoanAmount'].mean()
# Out:
# 146.41216216216216

# %%
df['Loan_Amount_Term'].sum()
# Out:
# 205200.0

# %%
#computes the median(middle value) of a column or row
df['ApplicantIncome'].median()
# Out:
# 3812.5

# %%
df['CoapplicantIncome'].max()
# Out:
# 41667.0

# %%
df['CoapplicantIncome'].min()
# Out:
# 0.0

# %%
#visualisation 
#Seaborn is a library that provides additional visualization tools built on top of Matplotlib.


import seaborn as sb
import matplotlib.pyplot as plt

#check available themes
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("classic")

# %%
sb.countplot(x=df['Gender'], palette = 'magma')
plt.title("Distribution of Gender Status")
plt.xlabel('Gender')
plt.ylabel('Number of Members')
# Out:
# Text(0, 0.5, 'Number of Members')

# %%
import numpy 
sb.barplot(x = 'Gender', y = 'LoanAmount', data = df, estimator=numpy.mean, palette = 'magma', hue='Education')
plt.title("Correlation between gender,loanAmount and education")
plt.xlabel('Gender')
plt.ylabel('Loan Amount')
# Out:
# c:\Users\user\Desktop\Data Science\DAY01\env\Lib\site-packages\numpy\lib\nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# Text(0, 0.5, 'Loan Amount')

# %%
sb.swarmplot(x ='Gender', y ='ApplicantIncome', data = df, palette= 'magma',hue ='Self_Employed')
# Out:
# c:\Users\user\Desktop\Data Science\DAY01\env\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 37.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>
# c:\Users\user\Desktop\Data Science\DAY01\env\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 64.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\user\Desktop\Data Science\DAY01\env\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 28.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sb.scatterplot(x ='LoanAmount', y ='ApplicantIncome', data = df, palette= 'magma', hue = 'Gender')
# Out:
# <Axes: xlabel='LoanAmount', ylabel='ApplicantIncome'>

# %%
df.groupby("Property_Area").size().plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
df.groupby("Married").size().plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
df.groupby("Gender").size().plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
df.groupby("Education").size().plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
fruits = ["apples","bannas","oranges","grapes","mangoes"]
sizes = [20,10,10,30,20]
plt.pie(sizes, labels=fruits, autopct = "%1.1f%%" )
plt.show()
